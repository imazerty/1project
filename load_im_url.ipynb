# %% [markdown]
# <a href="https://colab.research.google.com/github/imazerty/1project/blob/master/load_im_url.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import time
start=time.time()
link = "/content/images_tags_and_labels.xlsx"
df = pd.read_excel(link)
stop= time.time()
print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))
# Out:
# durée: 0.0 min 0.2965 sec

# %%
df.head(5).T

# %%
url = df1.URL[0]

# %%
df1 = df.iloc[:,[2,6,7]]
df1.head(2)
# Out:
#       file_name   tag                                                URL
# 0  G0193231.JPG  I, R  http://162.38.140.205/tmp/Deep_mapping/session...
# 1  G0195741.JPG     B  http://162.38.140.205/tmp/Deep_mapping/session...

# %%
import urllib.request
start=time.time()
a=urllib.request.urlretrieve(url, 'image.jpg')
stop=time.time()
print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))
# Out:
# durée: 0.0 min 0.3359 sec

# %%
import IPython
from IPython.display import Image, display
start=time.time()


a = IPython.display.Image(url,width=255, height=255)

stop=time.time()

print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))
display(a)
# Out:
# durée: 0.0 min 0.3376 sec

# %%
from PIL import Image
import requests
import urllib
start=time.time()
im = Image.open(urllib.request.urlopen(url))
stop=time.time()
print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))
# Out:
# durée: 0.0 min 0.3409 sec

# %%
import requests
from PIL import Image
import io
import cv2
start=time.time()
response = requests.get(url,stream=True).content

im = Image.open(io.BytesIO(response))
stop=time.time()

print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))
# Out:
# durée: 0.0 min 0.3431 sec

# %%
import shutil
import requests
from PIL import Image
start=time.time()
response = requests.get(url, stream=True)
with open('my_image.png', 'wb') as file:
    shutil.copyfileobj(response.raw, file)
del response
img = Image.open('my_image.png')
stop=time.time()
print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))

img.show()
# Out:
# durée: 0.0 min 0.3445 sec

# %%
from skimage import io
import matplotlib.pyplot as plt
start=time.time()
image = io.imread(url)
stop=time.time()

print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))

plt.imshow(image)
plt.show()
# Out:
# durée: 0.0 min 0.5163 sec
